# %%
import sys
sys.path.append("/Users/fei/Documents/Github/deep-histopath")

# %%
import tensorflow as tf

# %%
from models.unet.unet_train import examine_model_inputs

# %%
examine_model_inputs(num_tiles=36, num_tile_per_row=12, num_tiles_per_img=128, tile_height=128, tile_width=128)

# %%
examine_model_inputs(num_tiles=36, num_tile_per_row=12, num_tiles_per_img=128*4, tile_height=128, tile_width=128)

# %%
examine_model_inputs(num_tiles=36, num_tile_per_row=12, num_tiles_per_img=128, tile_height=64, tile_width=64)
